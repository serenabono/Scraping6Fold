# %% [markdown]
# ### Importing Datasets

# %%
# %cd "/content/"
# !sudo apt-get install git-lfs
# !git lfs install
# Out:
# /content
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.3.4-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 27 not upgraded.
# Error: Failed to call git rev-parse --git-dir --show-toplevel: "fatal: not a git repository (or any of the parent directories): .git\n"
# Git LFS initialized.

# %%
import os
from getpass import getpass

# %cd "/content/"
user = 'serenabono'
# create your own access tocken
password = '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'
os.environ['GITHUB_AUTH'] = user + ':' + password
# !git lfs clone https://$GITHUB_AUTH@github.com/serenabono/Scraping6Fold.git
# Out:
# /content
# WARNING: 'git lfs clone' is deprecated and will not be updated
#           with new flags from 'git clone'
#
# 'git clone' has been updated in upstream Git to have comparable
# speeds to 'git lfs clone'.
# Cloning into 'Scraping6Fold'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 163 (delta 16), reused 35 (delta 10), pack-reused 120
# Receiving objects: 100% (163/163), 46.60 MiB | 12.77 MiB/s, done.
# Resolving deltas: 100% (78/78), done.
# Git LFS: (4 of 4 files) 123.03 MB / 123.03 MB

# %%
import pandas as pd 

# importing dataset
# %cd '/content/Scraping6Fold'

# 6Fold
six_fold_bios = pd.read_csv('bios.csv')
six_fold_table_drop_down_menu = pd.read_csv('table_drop_down_menu.csv')
six_fold_table_with_names = pd.read_csv('table_with_names.csv')
six_fold_text_dataset = pd.read_csv('text_dataset.csv')
# Out:
# /content/Scraping6Fold

# %%
six_fold_table_with_names
# Out:
#                                                       id  \
# 0      https://www.sixfold.org/doc?id=86d51ea7b499477...
# 1      https://www.sixfold.org/doc?id=bd2828a4f140fb3...
# 2      https://www.sixfold.org/doc?id=0abb870d0c5f285...
# 3                                                    NaN
# 4      https://www.sixfold.org/doc?id=07a491d654823cd...
# ...                                                  ...
# 11904                                                NaN
# 11905                                                NaN
# 11906  https://www.sixfold.org/doc?id=219e5515d9c3f3c...
# 11907  https://www.sixfold.org/doc?id=6cedd0e99e190d5...
# 11908                                                NaN
#
#                      context context_type  \
# 0      November 2021 Fiction      fiction
# 1      November 2021 Fiction      fiction
# 2      November 2021 Fiction      fiction
# 3      November 2021 Fiction      fiction
# 4      November 2021 Fiction      fiction
# ...

# %%
six_fold_text_dataset
# Out:
#                                                      id  \
# 0     https://www.sixfold.org/doc?id=86d51ea7b499477...
# 1     https://www.sixfold.org/doc?id=bd2828a4f140fb3...
# 2     https://www.sixfold.org/doc?id=0abb870d0c5f285...
# 3     https://www.sixfold.org/doc?id=07a491d654823cd...
# 4     https://www.sixfold.org/doc?id=ab3ac1066fb63a4...
# ...                                                 ...
# 8741  https://www.sixfold.org/doc?id=32fabc28e236950...
# 8742  https://www.sixfold.org/doc?id=b4880cf288c12b3...
# 8743  https://www.sixfold.org/doc?id=f0bd0a1d31ed85b...
# 8744  https://www.sixfold.org/doc?id=219e5515d9c3f3c...
# 8745  https://www.sixfold.org/doc?id=6cedd0e99e190d5...
#
#                                                    text
# 0     Carrow / 1 \n\nMamochka \n\nMarch, 1945, Budap...
# 1                      4677 words \n\nAn Uprising \n...
# 2     Grief \n\n1 \n\nIt's been three hours since th...
# 3                     approx. 3,900 words \n\nBenny ...
# ...

# %%
merged_dataset = six_fold_text_dataset.merge(six_fold_table_with_names, left_on='id', right_on='id')
merged_dataset
# Out:
#                                                      id  \
# 0     https://www.sixfold.org/doc?id=86d51ea7b499477...
# 1     https://www.sixfold.org/doc?id=bd2828a4f140fb3...
# 2     https://www.sixfold.org/doc?id=0abb870d0c5f285...
# 3     https://www.sixfold.org/doc?id=07a491d654823cd...
# 4     https://www.sixfold.org/doc?id=ab3ac1066fb63a4...
# ...                                                 ...
# 8741  https://www.sixfold.org/doc?id=32fabc28e236950...
# 8742  https://www.sixfold.org/doc?id=b4880cf288c12b3...
# 8743  https://www.sixfold.org/doc?id=f0bd0a1d31ed85b...
# 8744  https://www.sixfold.org/doc?id=219e5515d9c3f3c...
# 8745  https://www.sixfold.org/doc?id=6cedd0e99e190d5...
#
#                                                    text  \
# 0     Carrow / 1 \n\nMamochka \n\nMarch, 1945, Budap...
# 1                      4677 words \n\nAn Uprising \n...
# 2     Grief \n\n1 \n\nIt's been three hours since th...
# 3                     approx. 3,900 words \n\nBenny ...
# ...

# %%
merged_dataset['round1'] = pd.to_numeric(merged_dataset['round1'], errors='coerce')
merged_dataset = merged_dataset.dropna(subset=['round1'])
merged_dataset = merged_dataset.dropna(subset=['text'])
merged_dataset
# Out:
#                                                      id  \
# 0     https://www.sixfold.org/doc?id=86d51ea7b499477...
# 1     https://www.sixfold.org/doc?id=bd2828a4f140fb3...
# 2     https://www.sixfold.org/doc?id=0abb870d0c5f285...
# 3     https://www.sixfold.org/doc?id=07a491d654823cd...
# 4     https://www.sixfold.org/doc?id=ab3ac1066fb63a4...
# ...                                                 ...
# 8711  https://www.sixfold.org/doc?id=09f5d70b596df69...
# 8712  https://www.sixfold.org/doc?id=1482e1a9dd0abd9...
# 8713  https://www.sixfold.org/doc?id=e7f8c7813b79703...
# 8714  https://www.sixfold.org/doc?id=a359f14b9036b52...
# 8715  https://www.sixfold.org/doc?id=d317908ca2ec4d3...
#
#                                                    text  \
# 0     Carrow / 1 \n\nMamochka \n\nMarch, 1945, Budap...
# 1                      4677 words \n\nAn Uprising \n...
# 2     Grief \n\n1 \n\nIt's been three hours since th...
# 3                     approx. 3,900 words \n\nBenny ...
# ...

# %%
import re
import random
def clean_text(text):
  try:
    text = random.choice([sentence for sentence in re.findall(r".*?[\.\!\?]+", text)])
    text = text.lower()
    text = text.replace(u'\xa0', u'')
    text = text.replace(u'\x0c', u'')
    text = text.replace(u'\n', u' ')
    text = text.replace(u'\t', u'')
    text = text.replace(u'\r', u'')
    text = text.replace(u'/', u'')
  except:
    pass
  return text

# %%
merged_dataset['cleaned_description'] = merged_dataset.text.apply(clean_text)
merged_dataset["round1"] = merged_dataset["round1"] + merged_dataset["round1"]

# %%
from sklearn.model_selection import train_test_split
val_size = 0.1
seed = 42
train_data, val_data, train_labels, val_labels = \
            train_test_split(merged_dataset["cleaned_description"], merged_dataset["round1"], test_size=val_size, 
                             random_state=seed)

# %%
val_labels
# Out:
# 6607     5.50
# 217     10.00
# 5894     7.34
# 3079     8.00
# 1548     8.80
#         ...
# 426     10.40
# 5341     7.00
# 1005     9.20
# 683      7.00
# 5605     8.00
# Name: round1, Length: 666, dtype: float64

# %%
import json
length = len(merged_dataset['cleaned_description'])

jsondict = {}
jsondict["normal"] = list(merged_dataset['cleaned_description'][:length//2].values)
jsondict["beautiful"] = list(merged_dataset['cleaned_description'][length//2:].values)

with open("dataset.json", "w") as outfile:
    json.dump(jsondict, outfile)

# %%
jsondict
# Out:
# {'normal': ['i shake my head a little too forcefully and answer in hungarian.',
#   'woman, one with experience of a certain kind, i am sure.',
#   'she just burst out, “oh, elle!',
#   '” the girl yells as they get close.',
#   ' her glass is always half full as the saying goes.',
#   ' “something is finally ready for you.',
#   ' the picture of innocence.',
#   '“i don’t care what happens to him.',
#   'return.',
#   ' you see?',
#   'jake mumbled an okay.',
#   'then, without even knowing my grandfather, james swann came to the rescue in 1971.',
#   ' she is silent.',
#   'his weight furiously from foot to foot.',
#   ' these trees weren’t much more than saplings then.',
#   'the man sighs through his brown teeth, derisive.',
#   'never doing it.',
#   'into two.',
#   ' “just a vibration to let me know i’m on track.',
#   ' “do we need to drug a nine-year-old?',
#   'it is two in the morning.',
#   ' it was a sad smile.',
# ...

# %%
# !pip install transformers
# !pip install Sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 7.8 MB/s
# ...
#      |████████████████████████████████| 120 kB 75.8 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 59.3 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.3 MB 7.7 MB/s
# ...

# %%
from transformers import CamembertTokenizer
tokenizer = CamembertTokenizer.from_pretrained('camembert-base')
encoded_corpus = tokenizer(text=train_data.tolist(),
                            add_special_tokens=True,
                            padding='max_length',
                            truncation='longest_first',
                            max_length=300,
                           return_attention_mask=True)

input_ids = encoded_corpus['input_ids']
attention_mask = encoded_corpus['attention_mask']

# %%
import numpy as np
input_ids = np.array(input_ids)
attention_mask = np.array(attention_mask)
labels = train_labels.astype('float32').to_numpy()

# %%
from sklearn.model_selection import train_test_split
test_size = 0.1
seed = 42
train_inputs, test_inputs, train_labels, test_labels = \
            train_test_split(input_ids, labels, test_size=test_size, 
                             random_state=seed)
train_masks, test_masks, _, _ = train_test_split(attention_mask, 
                                        labels, test_size=test_size, 
                                        random_state=seed)

# %%
train_inputs.shape, train_labels.shape
# Out:
# ((5392, 300), (5392,))

# %%
from sklearn.preprocessing import StandardScaler
price_scaler = StandardScaler()
price_scaler.fit(train_labels.reshape(-1, 1))
train_labels = price_scaler.transform(train_labels.reshape(-1, 1))
test_labels = price_scaler.transform(test_labels.reshape(-1, 1))

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
batch_size = 32
def create_dataloaders(inputs, masks, labels, batch_size):
    input_tensor = torch.tensor(inputs)
    mask_tensor = torch.tensor(masks)
    labels_tensor = torch.tensor(labels)
    dataset = TensorDataset(input_tensor, mask_tensor, 
                            labels_tensor)
    dataloader = DataLoader(dataset, batch_size=batch_size, 
                            shuffle=True)
    return dataloader
train_dataloader = create_dataloaders(train_inputs, train_masks, 
                                      train_labels, batch_size)
test_dataloader = create_dataloaders(test_inputs, test_masks, 
                                     test_labels, batch_size)

# %%
import torch.nn as nn
from transformers import CamembertModel
class CamembertRegressor(nn.Module):
    
    def __init__(self, drop_rate=0.2, freeze_camembert=False):
        
        super(CamembertRegressor, self).__init__()
        D_in, D_out = 768, 1
        
        self.camembert = \
                   CamembertModel.from_pretrained('camembert-base')
        self.regressor = nn.Sequential(
            nn.Dropout(drop_rate),
            nn.Linear(D_in, D_out))
    def forward(self, input_ids, attention_masks):
        
        outputs = self.camembert(input_ids, attention_masks)
        class_label_output = outputs[1]
        outputs = self.regressor(class_label_output)
        return outputs
model = CamembertRegressor(drop_rate=0.2)
# Out:
# ...
# Some weights of the model checkpoint at camembert-base were not used when initializing CamembertModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.dense.bias']
# - This IS expected if you are initializing CamembertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing CamembertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import torch
if torch.cuda.is_available():       
    device = torch.device("cuda")
    print("Using GPU.")
else:
    print("No GPU available, using the CPU instead.")
    device = torch.device("cpu")
model.to(device)
# Out:
# Using GPU.
# CamembertRegressor(
#   (camembert): CamembertModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(32005, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0): RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
# ...

# %%
from transformers import AdamW
optimizer = AdamW(model.parameters(),
                  lr=5e-5,
                  eps=1e-8)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,

# %%
from transformers import get_linear_schedule_with_warmup
epochs = 15
total_steps = len(train_dataloader) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer,       
                 num_warmup_steps=0, num_training_steps=total_steps)

# %%
loss_function = nn.MSELoss()

# %%
from torch.nn.utils.clip_grad import clip_grad_norm

def train(model, optimizer, scheduler, loss_function, epochs,       
          train_dataloader, device, clip_value=2):
    for epoch in range(epochs):
        print(epoch)
        print("-----")
        best_loss = 1e10
        model.train()
        for step, batch in enumerate(train_dataloader): 
            print(step)  
            batch_inputs, batch_masks, batch_labels = \
                               tuple(b.to(device) for b in batch)
            model.zero_grad()
            outputs = model(batch_inputs, batch_masks)           
            loss = loss_function(outputs.squeeze(), 
                             batch_labels.squeeze())
            loss.backward()
            clip_grad_norm(model.parameters(), clip_value)
            optimizer.step()
            scheduler.step()
                
    return model
model = train(model, optimizer, scheduler, loss_function, epochs, 
              train_dataloader, device, clip_value=2)
# Out:
# 0
# -----
# 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-be8b90078bda> in <module>
#      23     return model
#      24 model = train(model, optimizer, scheduler, loss_function, epochs,
# ---> 25               train_dataloader, device, clip_value=2)
#
# <ipython-input-24-be8b90078bda> in train(model, optimizer, scheduler, loss_function, epochs, train_dataloader, device, clip_value)
#      16             loss = loss_function(outputs.squeeze(),
#      17                              batch_labels.squeeze())
# ---> 18             loss.backward()
#      19             clip_grad_norm(model.parameters(), clip_value)
#      20             optimizer.step()
#
# ...

# %% [markdown]
# ### Saving finetuned model

# %%
output_model = './Bert_finetuned_on_6fold.pth'
def save(model, optimizer):
    # save
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }, output_model)

save(model, optimizer)

# %%
def evaluate(model, loss_function, test_dataloader, device):
    model.eval()
    test_loss, test_r2 = [], []
    for batch in test_dataloader:
        batch_inputs, batch_masks, batch_labels = \
                                 tuple(b.to(device) for b in batch)
        with torch.no_grad():
            outputs = model(batch_inputs, batch_masks)
        loss = loss_function(outputs, batch_labels)
        test_loss.append(loss.item())
        r2 = r2_score(outputs, batch_labels)
        test_r2.append(r2.item())
    return test_loss, test_r2
def r2_score(outputs, labels):
    labels_mean = torch.mean(labels)
    ss_tot = torch.sum((labels - labels_mean) ** 2)
    ss_res = torch.sum((labels - outputs) ** 2)
    r2 = 1 - ss_res / ss_tot
    return r2

# %%
def predict(model, dataloader, device):
    model.eval()
    output = []
    for batch in dataloader:
        batch_inputs, batch_masks, _ = \
                                  tuple(b.to(device) for b in batch)
        with torch.no_grad():
            output += model(batch_inputs, 
                            batch_masks).view(1,-1).tolist()[0]
    return output

# %%
encoded_val_corpus = \
                tokenizer(text=val_data.tolist(),
                          add_special_tokens=True,
                          padding='max_length',
                          truncation='longest_first',
                          max_length=300,
                          return_attention_mask=True)
val_input_ids = np.array(encoded_val_corpus['input_ids'])
val_attention_mask = np.array(encoded_val_corpus['attention_mask'])
val_labels = val_labels.to_numpy()
val_labels = price_scaler.transform(val_labels.reshape(-1, 1))
val_dataloader = create_dataloaders(val_input_ids, 
                         val_attention_mask, val_labels, batch_size)
y_pred_scaled = predict(model, val_dataloader, device)

# %%
y_test = np.asarray(val_labels).reshape([-1,1])
y_pred = price_scaler.inverse_transform(np.asarray(y_pred_scaled).reshape([-1,1]))

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

mae = mean_absolute_error(y_test, y_pred)
mdae = median_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mdape = ((pd.Series(y_test.reshape([-1,])) - pd.Series(y_pred.reshape([-1,])))\
         / pd.Series(y_test.reshape([-1,]))).abs().median()
r_squared = r2_score(y_test, y_pred)
pearson = pearsonr(y_test.ravel(), y_pred.ravel())

{"mean_absolute_error":mae, "median_absolute_error": mdae, "mean_squared_error": mse, "mean_absolute_percentage_error": mape , "mean_square_error": mdape, "r2_score": r_squared, "pearson": pearson}
# Out:
# {'mean_absolute_error': 7.061438853149231,
#  'median_absolute_error': 6.999113638035298,
#  'mean_squared_error': 50.83672205705579,
#  'mean_absolute_percentage_error': 25.97488623031561,
#  'mean_square_error': 9.880992449897757,
#  'r2_score': -51.143115345113415,
#  'pearson': (0.0478405538030352, 0.2175732113363676)}
